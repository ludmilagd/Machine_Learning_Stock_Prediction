# %%
import dash
import dash_core_components as dcc
import dash_html_components as html
import pandas as pd
import plotly.graph_objs as go #no instalado 
from dash.dependencies import Input, Output #no instalado
import numpy as np
import datetime as dt
import pandas_datareader as web

# %%
# LG read
import datetime as dt
import pandas_datareader as web
start = dt.datetime(1980,1,1)
end = dt.datetime.now()
df = web.DataReader('AAPL','yahoo', start, end)

df=df.reset_index()
df["Date"]=pd.to_datetime(df.Date,format="%Y-%m-%d")
df.to_csv('AAPL_1980-2020_Historical.csv')


# df.index=df['Date']

# %%
app = dash.Dash()
server = app.server

# %%
models.to_csv('Models.csv')

# %%
# model_cvs= pd.read_csv("model_data.csv")

start = dt.datetime(2010,1,1)
end = dt.datetime.now()
df = web.DataReader('AAPL','yahoo', start, end)
df.to_csv('YahooFinance_data.csv')

df.head()
df=df.reset_index()

df["Date"]=pd.to_datetime(df.Date,format="%Y-%m-%d")
df.index=df['Date']

df.head()
# Out:
#                  Date      High       Low      Open     Close       Volume  \
# Date
# 2010-01-04 2010-01-04  7.660714  7.585000  7.622500  7.643214  493729600.0
# 2010-01-05 2010-01-05  7.699643  7.616071  7.664286  7.656429  601904800.0
# 2010-01-06 2010-01-06  7.686786  7.526786  7.656429  7.534643  552160000.0
# 2010-01-07 2010-01-07  7.571429  7.466071  7.562500  7.520714  477131200.0
# 2010-01-08 2010-01-08  7.571429  7.466429  7.510714  7.570714  447610800.0
#
#             Adj Close
# Date
# 2010-01-04   6.583586
# 2010-01-05   6.594968
# 2010-01-06   6.490066
# 2010-01-07   6.478067
# 2010-01-08   6.521136

# %%
data=df.sort_index(ascending=True,axis=0)
new_data=pd.DataFrame(index=range(0,len(df)),columns=['Date','Close'])

for i in range(0,len(data)):
    new_data["Date"][i]=data['Date'][i]
    new_data["Close"][i]=data["Close"][i]
    
new_data.head()

# %%
new_data=new_data.set_index('Date')
new_data.head()

# %%
new_data.index

# %%
dataset=new_data.values
dataset

# %%
# df= pd.read_csv("stock_data.csv")

tickers = ['TSLA','AAPL','FB','MSFT','SBUX']
df1 = web.DataReader(tickers, data_source='yahoo', start='2017-01-01', end=dt.datetime.now())
df1.head()

# %%
# Other companies stock price
df=df1.stack().reset_index().rename(index=str, columns={"level_1": "Symbols"}).sort_values(['Symbols','Date'])
df.rename(columns={'Symbols':'Stock'}, inplace=True)

# %%
df.head()

# %%
# df1 = px.data.stocks(indexed=True)-1
# fig = px.area(df1, facet_col="Stock", facet_col_wrap=2)
# fig.show()

# %%
# # Readinf-Model Data (mocking table)
# model_data_Index=model_cvs.set_index('Date')
# model_data_Index.head()

# %%
# model_data= pd.read_csv("model_data.csv")

# %%
# using plotly express- not used
fig = px.line(model_data, x='Date', y=['Train', 'Validation', 'M1', 'M2', 'M3'])

fig.update_layout(
    showlegend=True,
    plot_bgcolor="white",
    xaxis_title="Date",
    yaxis_title="Closing Rate Predicted",
    legend_title="Data:",
    margin=dict(t=50,l=50,b=50,r=50),
    xaxis=go.layout.XAxis(
        rangeselector=dict(
            buttons=list([
                dict(count=1, label="1m", step="month", stepmode="backward"),
                dict(count=6, label="6m", step="month", stepmode="backward"),
                dict(count=1, label="YTD", step="year", stepmode="todate"),
                dict(count=1, label="1y", step="year", stepmode="backward"),
                dict(step="all")
            ])
        ),
        rangeslider=dict(visible=True)
        
    )

)

# %%
#  range selector and range-test
    xaxis={"title":"Date",
                   'rangeselector': {'buttons': list([{'count': 1, 'label': '1M', 
                                                       'step': 'month', 
                                                       'stepmode': 'backward'},
                                                      {'count': 6, 'label': '6M', 
                                                       'step': 'month', 
                                                       'stepmode': 'backward'},
                                                      {'step': 'all'}])},
                   'rangeslider': {'visible': True}, 'type': 'date'},

# %%
# create figure lines with plotly express-not used
fig = px.line(model_data, x='Date', y=['Train', 'Validation', 'M1', 'M2', 'M3'],title="titulo")

fig.update_layout(
    showlegend=True,
    plot_bgcolor="white",
    xaxis_title="Date",
    yaxis_title="Closing Rate Predicted",
    legend_title="Data:",
    margin=dict(t=50,l=50,b=50,r=50),

)

fig.update_xaxes(
    rangeslider_visible=True,
#     type="date",
    rangeselector=dict(visible=True,
        buttons=list([
            dict(count=1, label="1m", step="month", stepmode="backward"),
            dict(count=6, label="6m", step="month", stepmode="backward"),
            dict(count=1, label="YTD", step="year", stepmode="todate"),
            dict(count=1, label="1y", step="year", stepmode="backward"),
            dict(step="all")
        ])
       
    )
)
fig.update_xaxes(showline=True, linewidth=2, linecolor='white', gridcolor='lightgray')
fig.update_yaxes(showline=True, linewidth=2, linecolor='white', gridcolor='lightgray')

# Show plot 
fig.show()

# %%
# model_data["Train"]

# %%
# LSTM graph
D_validationData= pd.read_csv("LSTM_validation.csv")
D_train_data= pd.read_csv("LSTM_train.csv")
D_train_data  
D_validationData

# %%
# create figure lines with go-LSTM
fig2 = go.Figure()
fig2.add_trace(go.Scatter(x=D_validationData["Date"], y=D_validationData["Close"],
                    mode='lines',
                    name='Validation',
                    line=dict(color="blue",width=4)))
fig2.add_trace(go.Scatter(x=D_validationData["Date"], y=D_validationData["Predictions"],
                    mode='lines',
                    name='Predictions',
                    line=dict(color="red",width=4)))
fig2.add_trace(go.Scatter(x=D_train_data["Date"], y=D_train_data["Close"],
                    mode='lines', name='Train',
                    line=dict(color="darkgreen",width=4)))



fig2.update_layout(hovermode='x unified',
    showlegend=True,
    plot_bgcolor="white",
    paper_bgcolor = "rgba(0,0,0,0)",
    xaxis_title="Date",
    yaxis_title="Closing Rate Predicted",
    legend_title="Data:",
    margin=dict(t=50,l=50,b=50,r=50),
    
)
fig2.update_xaxes(showline=True, linewidth=2, linecolor='white', gridcolor='lightgray')
fig2.update_yaxes(showline=True, linewidth=2, linecolor='white', gridcolor='lightgray')

fig2.show()

# %%
# Moving Average graph
moving_avg= pd.read_csv("test_mov_avg.csv")
moving_avg

# %%
# create figure lines Moving Average
fig3 = go.Figure()
fig3.add_trace(go.Scatter(x=moving_avg["date"], y=moving_avg["close"],
                    mode='lines',
                    name='Test',
                    line=dict(color="blue",width=4)))
fig3.add_trace(go.Scatter(x=moving_avg["date"], y=moving_avg["est_N2"],
                    mode='lines',
                    name='Predictions using Moving Average',
                    line=dict(color="red",width=4)))

fig3.update_layout(hovermode='x unified',
    showlegend=True,
    plot_bgcolor="white",
    paper_bgcolor = "rgba(0,0,0,0)",
    xaxis_title="Date",
    yaxis_title="Closing Rate Predicted",
    legend_title="Data:",
    margin=dict(t=50,l=50,b=50,r=50),
    
)
fig3.update_xaxes(showline=True, linewidth=1, linecolor='white', gridcolor='lightgray')
fig3.update_yaxes(showline=True, linewidth=1, linecolor='white', gridcolor='lightgray')

fig3.show()

# %%
# Tree Model graph
Tree_training= pd.read_csv("Tree_training_data.csv")
Tree_prediction= pd.read_csv("Tree_model_prediction.csv")
Tree_training.head(2)

# %%
# Create figure lines for Tree Model
figt = go.Figure()
figt.add_trace(go.Scatter(x=Tree_training["Date"], y=Tree_training["Close"],
                    mode='lines',
                    name='Training data',
                    line=dict(color="darkblue",width=2)))
figt.add_trace(go.Scatter(x=Tree_prediction["Date"], y=Tree_prediction["Close"],
                    mode='lines',
                    name='Validation',
                    line=dict(color="aqua",width=3)))
figt.add_trace(go.Scatter(x=Tree_prediction["Date"], y=Tree_prediction["Predictions"],
                    mode='lines', name='Predicted',
                    line=dict(color="red",width=1)))



figt.update_layout(hovermode='x unified',
    showlegend=True,
    plot_bgcolor="white",
    paper_bgcolor = "rgba(0,0,0,0)",
    xaxis_title="Date",
    yaxis_title="Closing Rate Predicted",
    legend_title="Data:",
    margin=dict(t=50,l=50,b=50,r=50),
    
)
figt.update_xaxes(showline=True, linewidth=2, linecolor='white', gridcolor='lightgray')
figt.update_yaxes(showline=True, linewidth=2, linecolor='white', gridcolor='lightgray')

figt.show()

# %%
# LR Model data
LR_train= pd.read_csv("LR_train.csv")
LR_prediction= pd.read_csv("LR_prediction.csv")

# %%
# Create figure lines for Linear Regression Model
figLR = go.Figure()
figLR.add_trace(go.Scatter(x=LR_train["Date"], y=LR_train["Close"],
                    mode='lines',
                    name='Training data',
                    line=dict(color="darkblue",width=2)))
figLR.add_trace(go.Scatter(x=LR_prediction["Date"], y=LR_prediction["Close"],
                    mode='lines',
                    name='Validation',
                    line=dict(color="aqua",width=3)))
figLR.add_trace(go.Scatter(x=LR_prediction["Date"], y=LR_prediction["Predictionslr"],
                    mode='lines', name='Predicted',
                    line=dict(color="red",width=1)))



figLR.update_layout(hovermode='x unified',
    showlegend=True,
    plot_bgcolor="white",
    paper_bgcolor = "rgba(0,0,0,0)",
    xaxis_title="Date",
    yaxis_title="Closing Rate Predicted",
    legend_title="Data:",
    margin=dict(t=50,l=50,b=50,r=50),
    
)
figLR.update_xaxes(showline=True, linewidth=2, linecolor='white', gridcolor='lightgray')
figLR.update_yaxes(showline=True, linewidth=2, linecolor='white', gridcolor='lightgray')

figLR.show()

# %%
app.layout = html.Div([
   
    html.H1("Apple Stock Price Prediction- Machine Learning & Python", style={'textAlign': 'center','color':'#07098d'}),
    html.H2("", style={'textAlign': 'center','color':'#07098d'}),
    dcc.Tabs(id="tabs", children=[
       
        dcc.Tab(label='LSTM',children=[
			html.Div([				
			    html.H2("Long Short-Term Memory (LSTM)", 
                        style={'textAlign': 'center'}),
                html.H3("TEST DATA  Long Short-Term Memory (LSTM) Long Short-Term Memory (LSTM) Long Short-Term Memory (LSTM) Long Short-Term Memory (LSTM) Long Short-Term Memory (LSTM) Long Short-Term Memory (LSTM) Long Short-Term Memory (LSTM) Long Short-Term Memory (LSTM) Long Short-Term Memory (LSTM) Long Short-Term Memory (LSTM) Long Short-Term Memory (LSTM) Long Short-Term Memory (LSTM)", 
                        style={'textAlign': 'left'}),

                dcc.Graph(id = 'GrapLTSM',
                        figure = fig2),
                     ]
                ),   		
        ]),


        dcc.Tab(label='Moving Average',children=[
			html.Div([				
			    html.H2("Moving Average to predict Apple Stock  Price", 
                        style={'textAlign': 'center'}),
                html.H3("TEST DATA  Moving Average to predict Apple Stock Moving Average to predict Apple Stock Moving Average to predict Apple Stock Moving Average to predict Apple Stock Moving Average to predict Apple StockMoving Average to predict Apple Stock  Price Moving Average to predict Apple Stock  Price", 
                        style={'textAlign': 'left'}),

                dcc.Graph(id = 'GrapMovingAvg',
                        figure = fig3),
                    ]
                ),
        ]),

        dcc.Tab(label='Tree Model and Linear Regression',children=[
			html.Div([				
			    html.H2("Apple Sock Price Prediction For the Last 30 Days - Tree Prediction Model", 
                        style={'textAlign': 'center'}),
                html.H3("Tree Model and Linear Regression Stock Prediction Tree Model and Linear Regression Stock Prediction Tree Model and Linear Regression Stock Prediction", 
                        style={'textAlign': 'left'}),

                dcc.Graph(id = 'GrapTreeLR',
                        figure = figt),
                

                html.H2("Apple Stock Price For The Last 30 Days - Linear Regression Model", 
                        style={'textAlign': 'center'}),
                html.H3("Tree Model and Linear Regression Stock Prediction Tree Model and Linear Regression Stock Prediction Tree Model and Linear Regression Stock Prediction", 
                        style={'textAlign': 'left'}),

                dcc.Graph(id = 'GrapLR',
                        figure = figLR),
            ],className="container"),
            
        ]),


        dcc.Tab(label='Stock Data other Companies', children=[
            html.Div([
                html.H2("Stocks Price comparison High and Lows", 
                        style={'textAlign': 'center','color':'#07098d'}),
                                      
                dcc.Dropdown(id='my-dropdown',
                             options=[{'label': 'Tesla', 'value': 'TSLA'},
                                      {'label': 'Starbucks','value': 'SBUX'},
                                      {'label': 'Apple','value': 'AAPL'}, 
                                      {'label': 'Facebook', 'value': 'FB'}, 
                                      {'label': 'Microsoft','value': 'MSFT'}], 
                             multi=True,value=['SBUX'],
                             style={"display": "block", "margin-left": "auto", 
                                    "margin-right": "auto", "width": "60%"}),
                dcc.Graph(id='highlow'),

                html.H2("Stocks Market Volume", style={'textAlign': 'center'}),
         
                dcc.Dropdown(id='my-dropdown2',
                             options=[{'label': 'Tesla', 'value': 'SBUX'},
                                      {'label': 'Starbucks', 'value': 'SBUX'},
                                      {'label': 'Apple','value': 'AAPL'}, 
                                      {'label': 'Facebook', 'value': 'FB'},
                                      {'label': 'Microsoft','value': 'MSFT'}], 
                             multi=True,value=['SBUX'],
                             style={"display": "block", "margin-left": "auto", 
                                    "margin-right": "auto", "width": "60%"}),
                dcc.Graph(id='volume')
            ], className="container"),
        ])
    ])
])

# %%
# create a tab with Models Comparison
dcc.Tab(label='Model Comparison', children=[
            html.Div([
                html.H2("Stock Price Prediction with different models", 
                        style={'textAlign': 'center','color':'#07098d'}),
                                      
                dcc.Dropdown(id='my-dropdownM',
                             options=[{'label': 'Long Short-Term Memory', 'value': 'Long Short-Term Memory'},
                                      {'label': 'Moving Average','value': 'Moving Average Model'},
                                      {'label': 'Tree Model','value': 'Tree Model'}, 
                                      {'label': 'Actual Close Price':'Actual Close Price'}
                                      {'label': 'Linear Regression', 'value': 'Linear Regression Model'}], 
                             multi=True,value=['Actual Close Price'],
                             style={"display": "block", "margin-left": "auto", 
                                    "margin-right": "auto", "width": "60%"}),
                dcc.Graph(id='models'),
                
            ], className="container"),
        ]),

# %%
# # create the models comparison graph with one df

# @app.callback(Output('models', 'figure'),
#               [Input('my-dropdownM', 'value')])
# def update_graph(selected_dropdown):
#     dropdown = {"Actual Close Price":"Actual Close Price","Long Short-Term Memory": "Long Short-Term Memory","Moving Average Model":"Moving Average","Tree Model": "Tree Model","Linear Regression Model": "Linear Regression",}
#     trace1 = []
#     trace2 = []
#     for model in selected_dropdown:
#         trace1.append(
#           go.Scatter(x=m_actual["Date"],
#                      y=m_actual["Prediction"],
#                      mode='lines', opacity=0.7, 
#                      name=f'Predicted Stock Price ',textposition='bottom center'))
        
#     data = [val for sublist in traces for val in sublist]
#     figure = {'data': data,
#               'layout': go.Layout(colorway=["#5E0DAC", '#FF4F00', '#375CB1', 
#                                             '#FF7400', '#FFF400', '#FF0056'],
#             height=600,
# #             title=f"High and Low Prices for {', '.join(str(dropdown[i]) for i in selected_dropdown)} Over Time",
#             xaxis={"title":"Date",
#                    'rangeselector': {'buttons': list([{'count': 1, 'label': '1M', 
#                                                        'step': 'month', 
#                                                        'stepmode': 'backward'},
#                                                       {'count': 6, 'label': '6M', 
#                                                        'step': 'month', 
#                                                        'stepmode': 'backward'},
#                                                       {'step': 'all'}])},
#                    'rangeslider': {'visible': True}, 'type': 'date'},
#              yaxis={"title":"Price (USD)"})}
#     return figure

# %%
# create the models comparison graph- diff data frames

@app.callback(Output('models', 'figure'),
              [Input('my-dropdownM', 'value')])

def update_graph(my-dropdownM):
    dropdown = {"Actual Close Price":"Actual Close Price","Long Short-Term Memory": "Long Short-Term Memory","Moving Average Model":"Moving Average","Tree Model": "Tree Model","Linear Regression Model": "Linear Regression",}
    trace1=[]  
    for model in my-dropdownM:  
            trace1.append(
                go.Scatter(x=models[models["Model"] == model]["Date"],
                           y=models[models["Model"] == model]["Predictions"],
                           mode='lines', opacity=0.7, 
                           name=f'High {dropdown[model]}',textposition='bottom center'))
    traces = [trace1]    
    data = [val for sublist in traces for val in sublist]
    figure = {'data': data,
              'layout': go.Layout(colorway=["#5E0DAC", '#FF4F00', '#375CB1', 
                                            '#FF7400', '#FFF400', '#FF0056'],
            height=600,
            title=f"High and Low Prices for {', '.join(str(dropdown[i]) for i in selected_dropdown)} Over Time",
            xaxis={"title":"Date",
                   'rangeselector': {'buttons': list([{'count': 1, 'label': '1M', 
                                                       'step': 'month', 
                                                       'stepmode': 'backward'},
                                                      {'count': 6, 'label': '6M', 
                                                       'step': 'month', 
                                                       'stepmode': 'backward'},
                                                      {'step': 'all'}])},
                   'rangeslider': {'visible': True}, 'type': 'date'},
             yaxis={"title":"Price (USD)"})}
    return figure

# %%
# COMPLETE code to get models table
l30=dt.datetime.now()- dt.timedelta(30)

# Actual
m_actual_df = web.DataReader('AAPL','yahoo', l30, dt.datetime.now())
m_actual_df=m_actual_df.reset_index()
m_actual=m_actual_df[['Date','Close']]
m_actual["Model"]="Actual Close Price"
m_actual.rename(columns={'Close':'Predictions'}, inplace=True)

# LR
m_LR=LR_prediction[['Date','Predictionslr']]
m_LR["Model"]="Linear Regression Model"
m_LR.rename(columns={'Predictionslr':'Predictions'}, inplace=True)


# Tree Prediction
m_tree=Tree_prediction[['Date','Predictions']]
m_tree["Model"]="Tree Model"

# Moving Average
m_MA=moving_avg[['date','est_N2']]
m_MA["Model"]="Moving Average Model"
m_MA.rename(columns={'est_N2':'Predictions','date':"Date"}, inplace=True)
m_MA["Date"]=pd.to_datetime(m_MA.Date,format="%Y-%m-%d")
m_MA1 = m_MA[(m_MA['Date']>(dt.datetime.now()- dt.timedelta(30))) & (m_MA['Date']<dt.datetime.now())] 

# Long short-term memory
D_validationData["Date"]=pd.to_datetime(D_validationData.Date,format="%Y-%m-%d")
m_LSTM=D_validationData[['Date','Predictions']]
m_LSTM["Model"]="Long Short-Term Memory"
m_LSTM1 = m_LSTM[(m_LSTM['Date']>(dt.datetime.now()- dt.timedelta(30))) & (m_LSTM['Date']<dt.datetime.now())]  


# Model table
frames=[m_tree,m_actual,m_LR,m_MA1,m_LSTM1]
models=pd.concat(frames)
models

# %%
# Moving Average
m_MA=moving_avg[['date','est_N2']]
m_MA["Model"]="Moving Average Model"
m_MA.rename(columns={'est_N2':'Predictions','date':"Date"}, inplace=True)
m_MA["Date"]=pd.to_datetime(m_MA.Date,format="%Y-%m-%d")
m_MA1 = m_MA[(m_MA['Date']>(dt.datetime.now()- dt.timedelta(30))) & (m_MA['Date']<dt.datetime.now())]
m_MA1

# %%
moving_avg= pd.read_csv("test_mov_avg.csv")
moving_avg.head(2)
# Out:
#    Unnamed: 0        date       open       high        low     close  \
# 0        7928  2012-05-17  77.901428  78.214287  75.731430  75.73143
# 1        7929  2012-05-18  76.279999  77.629997  74.597145  75.76857
#
#    adj_close     volume  month     est_N2
# 0  65.737991  179305000      5  68.156689
# 1  65.770210  183073100      5  66.727547

# %%
m_MA=moving_avg[['date','est_N2']]
m_MA.head(2)
# Out:
#          date     est_N2
# 0  2012-05-17  68.156689
# 1  2012-05-18  66.727547

# %%
m_MA["Model"]="Moving Average Model"
m_MA.head(2)
# Out:
# C:\Users\ludmi\anaconda3\envs\PythonAdv\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#          date     est_N2                 Model
# 0  2012-05-17  68.156689  Moving Average Model
# 1  2012-05-18  66.727547  Moving Average Model

# %%
m_MA.rename(columns={'est_N2':'Predictions','date':"Date"}, inplace=True)
m_MA.head(2)
# Out:
# C:\Users\ludmi\anaconda3\envs\PythonAdv\lib\site-packages\pandas\core\frame.py:4308: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#          Date  Predictions                 Model
# 0  2012-05-17    68.156689  Moving Average Model
# 1  2012-05-18    66.727547  Moving Average Model

# %%
m_MA["Date"]=pd.to_datetime(m_MA.Date,format="%Y-%m-%d")
m_MA1 = m_MA[(m_MA['Date']>(dt.datetime.now()- dt.timedelta(30))) & (m_MA['Date']<dt.datetime.now())]
m_MA.tail
# Out:
# C:\Users\ludmi\anaconda3\envs\PythonAdv\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# <bound method NDFrame.tail of            Date  Predictions                 Model
# 0    2012-05-17    68.156689  Moving Average Model
# 1    2012-05-18    66.727547  Moving Average Model
# 2    2012-05-21    65.754101  Moving Average Model
# 3    2012-05-22    67.686104  Moving Average Model
# 4    2012-05-23    69.334759  Moving Average Model
# ...         ...          ...                   ...
# 1976 2020-03-26   246.200005  Moving Average Model
# 1977 2020-03-27   251.980003  Moving Average Model
# 1978 2020-03-30   253.090004  Moving Average Model
# 1979 2020-03-31   251.275002  Moving Average Model
# 1980 2020-04-01   254.549995  Moving Average Model
#
# [1981 rows x 3 columns]>

# %%
@app.callback(Output('highlow', 'figure'),
              [Input('my-dropdown', 'value')])
def update_graph(selected_dropdown):
    dropdown = {"TSLA": "Tesla","SBUX":"Starbucks","AAPL": "Apple","FB": "Facebook","MSFT": "Microsoft",}
    trace1 = []
    trace2 = []
    for stock in selected_dropdown:
        trace1.append(
          go.Scatter(x=df[df["Symbols"] == stock]["Date"],
                     y=df[df["Symbols"] == stock]["High"],
                     mode='lines', opacity=0.7, 
                     name=f'High {dropdown[stock]}',textposition='bottom center'))
        trace2.append(
          go.Scatter(x=df[df["Symbols"] == stock]["Date"],
                     y=df[df["Symbols"] == stock]["Low"],
                     mode='lines', opacity=0.6,
                     name=f'Low {dropdown[stock]}',textposition='bottom center'))
    traces = [trace1, trace2]
    data = [val for sublist in traces for val in sublist]
    figure = {'data': data,
              'layout': go.Layout(colorway=["#5E0DAC", '#FF4F00', '#375CB1', 
                                            '#FF7400', '#FFF400', '#FF0056'],
            height=600,
            title=f"High and Low Prices for {', '.join(str(dropdown[i]) for i in selected_dropdown)} Over Time",
            xaxis={"title":"Date",
                   'rangeselector': {'buttons': list([{'count': 1, 'label': '1M', 
                                                       'step': 'month', 
                                                       'stepmode': 'backward'},
                                                      {'count': 6, 'label': '6M', 
                                                       'step': 'month', 
                                                       'stepmode': 'backward'},
                                                      {'step': 'all'}])},
                   'rangeslider': {'visible': True}, 'type': 'date'},
             yaxis={"title":"Price (USD)"})}
    return figure

# %%
@app.callback(Output('volume', 'figure'),
              [Input('my-dropdown2', 'value')])
def update_graph(selected_dropdown_value):
    dropdown = {"TSLA": "Tesla","AAPL": "Apple","FB": "Facebook","SBUX":"Starbucks","MSFT": "Microsoft",}
    trace1 = []
    for stock in selected_dropdown_value:
        trace1.append(
          go.Scatter(x=df[df["Symbols"] == stock]["Date"],
                     y=df[df["Symbols"] == stock]["Volume"],
                     mode='lines', opacity=0.7,
                     name=f'Volume {dropdown[stock]}', textposition='bottom center'))
    traces = [trace1]
    data = [val for sublist in traces for val in sublist]
    figure = {'data': data, 
              'layout': go.Layout(colorway=["#5E0DAC", '#FF4F00', '#375CB1', 
                                            '#FF7400', '#FFF400', '#FF0056'],
            height=600,
            title=f"Market Volume for {', '.join(str(dropdown[i]) for i in selected_dropdown_value)} Over Time",
            xaxis={"title":"Date",
                   'rangeselector': {'buttons': list([{'count': 1, 'label': '1M', 
                                                       'step': 'month', 
                                                       'stepmode': 'backward'},
                                                      {'count': 6, 'label': '6M',
                                                       'step': 'month', 
                                                       'stepmode': 'backward'},
                                                      {'step': 'all'}])},
                   'rangeslider': {'visible': True}, 'type': 'date'},
             yaxis={"title":"Transactions Volume"})}
    return figure



if __name__=='__main__':
	app.run_server(debug=True)
